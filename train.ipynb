# %%
# !pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.7 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/40.7 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 40.7/40.7 kB 385.5 kB/s eta 0:00:00
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# ...
#    ---------------------------------------- 0.0/756.5 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/756.5 kB ? eta -:--:--
#    --- ------------------------------------ 61.4/756.5 kB 1.1 MB/s eta 0:00:01
# ...

# %%
# !git clone https://github.com/mateushlsilva/dataset-api.git
# Out:
# Cloning into 'dataset-api'...
# remote: Enumerating objects: 48873, done.
# remote: Counting objects: 100% (14709/14709), done.
# remote: Compressing objects: 100% (11718/11718), done.
# ^Cceiving objects:   7% (3422/48873), 346.41 MiB | 20.25 MiB/s

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='/media/mateus/usarLinux/video/dataset-api/data.yaml', epochs=4, imgsz=640, deterministic=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.29 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.47 🚀 Python-3.10.13 torch-2.2.2+cu121 CPU (Intel Core(TM) i3-10100F 3.60GHz)
# ...

# %%
metrics = model.val()

# %%
predict = model("https://ultralytics.com/images/bus.jpg")

# %%
path = model.export(format="-")
